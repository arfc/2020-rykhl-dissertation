# %%
# %matplotlib notebook 
# Import modules
import math
import numpy as np
import matplotlib.pyplot
from matplotlib.ticker import FormatStrFormatter
from pyne import serpent
from pyne import nucname
from pyne import data
import re
import itertools

def elem_aaa(iso):
    m = re.match(r"(?P<letters>[a-zA-Z]+)(?P<the_rest>.+)$", iso)
    return [m.group('letters'), m.group('the_rest')]

def merge(a,b):
    final = np.zeros (len(a)+len(b))
    for i in range(len(a)):
        final[2*i]   = a[i]
        final[2*i+1] = b[i]
    return final

# %% [markdown]
# # Load following

# %%
dep_tap = serpent.parse_dep('/home/andrei2/Desktop/git/publications/2020-rykhl-dissertation/data/load-following/serpent_only/1_geo_base_zero_eps_1h_dep.m', make_mats=False)
res_tap = serpent.parse_res('/home/andrei2/Desktop/git/publications/2020-rykhl-dissertation/data/load-following/serpent_only/1_geo_base_zero_eps_1h_res.m')
t_indx_shutdown = 0

keff_tap1 = res_tap['IMP_KEFF']         # K-eff parsing from dictionary
keff_tap = keff_tap1[:,0]             # K-eff value
keff_error_tap = keff_tap1[:,1]         # K-eff standart deviation
days_tap = np.around(dep_tap['DAYS']*24.0, decimals=0)
mdens_tap = dep_tap['MAT_fuel_MDENS']        # mass density for each isotope in material 'fuel'
adens_tap = dep_tap['MAT_fuel_ADENS']
names_tap = dep_tap['NAMES'][0].split()                      # Names of isotopes parsed from *_dep.m file
tot_pow_b = res_tap['TOT_POWER'][:,0]
tot_pow_e = res_tap['TOT_POWER'][:,2]
tot_pow_err = res_tap['TOT_POWER'][:,1]

pow_level = 100*tot_pow_b[:-1]/max(tot_pow_b[:-1])
t_c = days_tap[:-1]+0.5*(days_tap[1:]-days_tap[:-1])
#tot_pow_b=np.insert(tot_pow_b,7,tot_pow_b[6])
#simp_power_load = np.concatenate( (100*np.ones(21),np.zeros(40),100*np.ones(31)) )
print(len(pow_level), len(t_c))
# Out:
# 21 21

# %%
dep_tap_endf = serpent.parse_dep('load_follow_0-100-0/100-2w-0-4d/tap100_0_100_endf/tap.ini_dep.m', make_mats=False)
res_tap_endf = serpent.parse_res('load_follow_0-100-0/100-2w-0-4d/tap100_0_100_endf/tap.ini_res.m')

keff_tap_endf = res_tap['IMP_KEFF']         # K-eff parsing from dictionary
keff_tap_endf = keff_tap_endf[:,0]             # K-eff value
#keff_error_tap_endf = keff_tap_endf[:,1]         # K-eff standart deviation
days_tap_endf = dep_tap_endf['DAYS']*24
mdens_tap_endf = dep_tap_endf['MAT_fuel_MDENS']        # mass density for each isotope in material 'fuel'
adens_tap_endf = dep_tap_endf['MAT_fuel_ADENS']
names_tap_endf = dep_tap_endf['NAMES'][0].split()                      # Names of isotopes parsed from *_dep.m file

# %%
#dep1 = serpent.parse_dep('load_follow_0-100-0/100-2w-0-4d/pwr/pwr_dep.m', make_mats=False)
#res1 = serpent.parse_res('load_follow_0-100-0/100-2w-0-4d/pwr/pwr_res.m')

dep1 = serpent.parse_dep('load_follow_0-100-0/100-2w-0-4d/pwr100_0_100/higher_load_res/pwr_dep.m', make_mats=False)
res1 = serpent.parse_res('load_follow_0-100-0/100-2w-0-4d/pwr100_0_100/higher_load_res/pwr_res.m')

keff_lf = res1['IMP_KEFF']         # K-eff parsing from dictionary
keff_2 = keff_lf[:,0]             # K-eff value
keff_error2 = keff_lf[:,1]         # K-eff standart deviation
days_lf = dep1['DAYS']*24.0
#days_pwr=np.insert(days_lf,7,days_lf[7]-0.001)
mdens = dep1['MAT_UO2_MDENS']        # mass density for each isotope in material 'fuel'
adens = dep1['MAT_UO2_ADENS']
mdens_gd = dep1['MAT_UO2Gd_MDENS']        # mass density for each isotope in material 'fuel'
adens_gd = dep1['MAT_UO2Gd_ADENS']
names = dep1['NAMES'][0].split()                      # Names of isotopes parsed from *_dep.m file

# %%
fig_keff = matplotlib.pyplot.figure(8, figsize=(7,5))
title = 'Load Following for TAP (6d on 100%\n with $\\epsilon_{Xe}=0.92$, shutdown for 11 hours with $\\epsilon_{Xe}=0$, \n then back to 100%)\n'
ax1 = fig_keff.add_subplot(111)
ax1.grid(True)
#ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
#ax1.plot(days_lf, keff_2, 'o-', color='g', label='PWR')
#ax1.fill_between(days_lf, keff_2-keff_error2, keff_2+keff_error2,alpha=0.7, 
#                edgecolor='#808080', facecolor='#BEBEBE', linewidth=0.5)

ax1.plot(days_tap, keff_tap, 'o-', color='blue', label='TAP')
ax1.fill_between(days_tap, keff_tap-keff_error_tap, keff_tap+keff_error_tap,alpha=0.7, 
                edgecolor='#808080', facecolor='#BEBEBE', linewidth=0.5)
#ax.plot(days_tap_endf, keff_tap_endf, 'x--', color='red', linewidth=0.5,label='TAP (ENDF)')
#ax1.legend(loc=7)
ax1.set_ylabel(r'$k_{eff}$', color='b', fontsize=14)
ax1.set_xlabel('Time step [h]', fontsize=14)
ax1.set_title(title)
#ax1.set_ylim([1.0064,1.0093])
#ax1.set_ylim(1.104, 1.124)
#ax1.set_xlim([0,max(days_tap)])
ax1.set_xlim(0,21)
ax1.tick_params('x', labelsize=12)
ax1.set_xticks(days_tap)
ax1.tick_params('y', colors='b', labelsize=14)
ax1.yaxis.set_major_formatter(FormatStrFormatter('%.5f'))

ax2=ax1.twinx()
ax2.bar(days_tap[:-1], 0.0, bottom=pow_level,color='#f77777', alpha=1, align='edge', width=0.99, ls="-",
        edgecolor='#fc0303', linewidth=2.5, fill=False)
ax2.plot([11,11.0001],[0, 100], c='red', alpha=1, linewidth=2.5)
ax2.set_ylim(-2,103)
ax2.set_ylabel('Power level [%]', color='r', fontsize=14)
ax2.tick_params('y', colors='r', labelsize=14)
fig_keff.tight_layout()
fig_keff.show()
#fig_keff.savefig('/home/andrei2/Desktop/git/publications/2020-rykhl-dissertation/dissertation/figures/ch4/lf_keff_test.png',bbox_inches='tight', dpi=700)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
rho = 1e+5*(keff_tap-keff_tap[t_indx_shutdown])

fig_rho = matplotlib.pyplot.figure(9)#, figsize=(10,6))
ax1 = fig_rho.add_subplot(111)
ax1.grid(True)
#ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.plot(days_tap, rho, 'o-', color='g') #,fillstyle='none')
ax1.fill_between(days_tap, rho-1e5*keff_error_tap, rho+1e5*keff_error_tap,
                alpha=1, edgecolor='#808080', facecolor='#BEBEBE', linewidth=0)
ax1.legend(loc=0)
ax1.set_ylabel('Reactivity [pcm]', color='g',fontsize=14)
ax1.set_xlabel('Time step [h]',  fontsize=14)
ax1.tick_params('y', colors='g', labelsize=14)
ax1.tick_params('x', labelsize=12)
ax1.set_xticks(days_tap)
ax1.set_title(title)
#ax.set_ylim([1,1.05])
ax1.set_xlim([0, 21])

ax2=ax1.twinx()
#ax2.plot(days_tap, 100*tot_pow_b/max(tot_pow_b), 'o-', color='r', markerfacecolor='None')
ax2.bar(days_tap[:-1], 0.0, bottom=pow_level,color='#f77777', alpha=1, align='edge', width=0.99, ls="-",
        edgecolor='#fc0303', linewidth=2.5, fill=False)
ax2.plot([11,11.0001],[0, 100], c='red', alpha=1, linewidth=2.5)

ax2.set_ylabel('Power level [%]', color='r', fontsize=14)
ax2.tick_params('y', colors='r', labelsize=14)
ax2.set_ylim(-2,103)

fig_rho.tight_layout()
fig_rho.show()
#fig_rho.savefig('/home/andrei2/Desktop/git/publications/2020-rykhl-dissertation/dissertation/figures/ch4/lf_rho_test.png',bbox_inches='tight', dpi=700)
print('Maximum reactivity drop after shutdown %f pcm' %(np.amin(rho[:-10])))
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# Maximum reactivity drop after shutdown -191.000000 pcm

# %%
target_iso = ['Xe135', 'I135']
color_d = {'Xe135' : 'blue', 'I135': 'red', 'Te135': 'orange'}
style_d = {'Xe135' : '-', 'I135': '--', 'Te135': '+--'}
#style = itertools.cycle(('-', '-', '--', '-', '-', '-'))
# Initialize figure
fig_10 = matplotlib.pyplot.figure(11, figsize=(6,5))
ax = fig_10.add_subplot(111)
ax.grid(True)

for i in target_iso:
    el_aaa = elem_aaa(i)
    iso_name = "$^{"+str(el_aaa[-1])+"}$"+str(el_aaa[0])
    ax.plot(days_tap, 1e+24*adens_tap[names_tap.index(i),:], fillstyle='none', label=iso_name)
    # style_d[i], color=color_d[i], 

ax.legend(loc=0, fontsize=12)
#ax.set_ylabel('Mass [t]')
#ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax.tick_params('y', labelsize=12)
ax.tick_params('x', labelsize=12)
ax.set_ylabel(r'Number density [1/cm$^3$]', fontsize=14)
#ax.set_ylabel(r'Mass density [g/cm$^3$]')
ax.set_xlabel('Time step [h]', fontsize=14)
#ax.set_title('Isotope mass density in material FUEL')
ax.set_xlim([0.0,15.0])
#ax.set_ylim([1.3e15,2.4e16])
# Zoom peak
#ax.set_xlim([10, 10.3])
#ax.set_ylim([0.82e15, 0.83e15])
#ax.set_ylim([1e-20, 1e16])

fig_10.tight_layout()
fig_10.show()
#fig_10.savefig('/home/andrei2/Desktop/git/publications/2019-rykhl-xenon-ans/figures/tap_vs_pwr_xe_i_density.png',bbox_inches='tight', dpi=900)

print('Xe135 concentration at t=0 %e 1/cm3; I135 st t=0 %e 1/cm3'
         %(1e24*adens_tap[names_tap.index('Xe135'),t_indx_shutdown], 1e24*adens_tap[names_tap.index('I135'),t_indx_shutdown]))
print('I135/Xe135 ratio at the beginning of the transient %f' 
        %(adens_tap[names_tap.index('I135'),0]/adens_tap[names_tap.index('Xe135'),t_indx_shutdown]))
print('Xe135 concentration peak at t=%f hrs' %(days_tap[int(np.argmax(adens_tap[names_tap.index('Xe135'),:-4]))]))
print(adens_tap[names_tap.index('Sm149'),:])
#print(days_tap[:-17])
# Out:
# <img src="data:image/png;base64,..." width="600">
# Xe135 concentration at t=0 1.918490e+14 1/cm3; I135 st t=0 1.712820e+15 1/cm3
# I135/Xe135 ratio at the beginning of the transient 8.927959
# Xe135 concentration peak at t=16.999992 hrs
# [2.26311e-09 2.28913e-09 2.31510e-09 2.34092e-09 2.36653e-09 2.39190e-09
#  2.41699e-09 2.44180e-09 2.46631e-09 2.49052e-09 2.51442e-09 2.53803e-09
#  2.56018e-09 2.58215e-09 2.60405e-09 2.62594e-09 2.64786e-09 2.66985e-09
#  2.69192e-09 2.71409e-09 2.73636e-09 2.75874e-09]

# %%
print(tot_pow_b[:5])
#print(adens_tap[names_tap.index('Xe135')])
#print(adens_tap[names_tap.index('Xe135'),14])
N_xe_0 = 1e+24*adens_tap[names_tap.index('Xe135'), t_indx_shutdown]

N_i_0 = 1e+24*adens_tap[names_tap.index('I135'), t_indx_shutdown]

t = days_tap[4:]
t = (t - days_tap[4])*3600 # to sec
print(t)

lamb_xe = data.decay_const('Xe-135')
lamb_i = data.decay_const('I-135')

#for i in range(1,len(N_xe)-1):
#    N_xe[i+1] = (N_xe[i]- N_i_d[i+1])* np.exp(-data.decay_const('Xe-135')*(t[i+1]-t[i])) 
N_xe = N_xe_0*np.exp(-lamb_xe*t) + \
    (N_i_0*lamb_i)/(lamb_i-lamb_xe)*(np.exp(-lamb_xe*t) - np.exp(-lamb_i*t))
N_i = N_i_0*np.exp(-lamb_i*t)

# Initialize figure
fig_11 = matplotlib.pyplot.figure(12) #, figsize=(10,6))
ax = fig_11.add_subplot(111)
ax.grid(True)
#ax.set_ylim(0,1.01)
for i in ['Xe135','I135']:#, names.index('U233'), names.index('U235')]:
    #ax.plot(days_lf, 1e+24*adens[names.index(i)], 'v--', label=i+'(PWR/Serpent)')
    ax.plot(days_tap, 1e+24*adens_tap[names_tap.index(i)], '--', label=i+'(TAP/Serpent)')
ax.plot(t/3600+days_tap[t_indx_shutdown], N_xe, 'x-', label='Xe135 (TAP/analytical)')
ax.plot(t/3600+days_tap[t_indx_shutdown], N_i, 'x--', label='I135 (TAP/analytical)')
ax.legend(loc=0)
#ax.set_ylabel('Mass [t]')
ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax.set_ylabel(r'Number density [1/cm$^3$]')
#ax.set_ylabel(r'Mass density [g/cm$^3$]')
ax.set_xlabel('Time step [h]')
ax.set_title('Isotope mass density in material FUEL')
ax.set_xlim([0,15])

#zoom peak Xe135
#ax.set_xlim([9, 10])
#ax.set_ylim([8.0e+14, 8.74e+14])
fig_11.tight_layout()
fig_11.show()
#fig_11.savefig('6_tap_vs_analytical_xe_i_density.png',bbox_inches='tight')
print('Xe135 peak concentration %e 1/cm3 at t=%f h' %(np.amax(N_xe),
                                                      t[int(np.argmax(N_xe))]/3600+days_tap[t_indx_shutdown]))
print('Or %f hr after shutdown' %(t[int(np.argmax(N_xe))]/3600))
# Out:
# [1.e-10 1.e-10 1.e-10 1.e-10 1.e-10]
# [    0.      3599.9424  7199.9712 10800.     14399.9424 17999.9712
#  21600.     25199.9424 28799.9712 32400.     35999.9424 39599.9712
#  43200.     46799.9424 50399.9712 54000.     57599.9424 61199.9712]
# <img src="data:image/png;base64,..." width="640">
# Xe135 peak concentration 8.217853e+14 1/cm3 at t=9.999984 h
# Or 9.999984 hr after shutdown

# %%
nom = lamb_xe*(lamb_i*(N_xe_0+N_i_0)-lamb_xe*N_xe_0)
den = lamb_i**2 * N_i_0
t_peak = np.log(nom/den) / (lamb_xe-lamb_i)

print('Analytical solution for the Xe-135 peak %f s, %f h' %(t_peak, t_peak/3600))

print('\nSecond method')
t = np.arange(0, 5*24*3600, 0.1)
N_xe = N_xe_0*np.exp(-lamb_xe*t) + \
    (N_i_0*lamb_i)/(lamb_i-lamb_xe)*(np.exp(-lamb_xe*t) - np.exp(-lamb_i*t))
print('Xe135 peak concentration %e 1/cm3 at t=%f h' %(np.amax(N_xe),
                                                      np.argmax(N_xe)/36000))
# Out:
# Analytical solution for the Xe-135 peak 36327.885322 s, 10.091079 h
#
# Second method
# Xe135 peak concentration 8.218127e+14 1/cm3 at t=10.091083 h
